# %% [markdown]
# <a href="https://colab.research.google.com/github/Mithun691/CIFAR10/blob/master/CIFAR10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

if torch.cuda.is_available():
  device=torch.device("cuda")
else:
  device=torch.device("cpu")

n_epochs=20
batch_size=25
learning_rate=0.1

transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))])
train_dataset=torchvision.datasets.CIFAR10(root="./data",train=True,transform=transform,download=True)
test_dataset=torchvision.datasets.CIFAR10(root="./data",train=False,transform=transform,download=True)
train_loader=torch.utils.data.DataLoader(dataset=train_dataset,batch_size=batch_size,shuffle=True)
test_loader=torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size,shuffle=False)

map_labels={0:"plane",1:"car",2:"bird",3:"cat",4:"deer",5:"dog",6:"frog",7:"horse",8:"ship",9:"truck"}
examples=iter(train_loader)
samples,labels=examples.next()
print(samples.shape,labels.shape)
images=samples.numpy()

for i in range(25):
  plt.subplot(5,5,i+1)
  img_view=np.moveaxis(images[i],0,2)
  plt.imshow(img_view)

for i in range(25):
  print(map_labels[labels[i].item()])

print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([25, 3, 32, 32]) torch.Size([25])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# deer
# frog
# frog
# bird
# frog
# bird
# dog
# ship
# frog
# frog
# truck
# cat
# ship
# bird
# cat
# car
# horse
# truck
# car
# cat
# plane
# horse
# deer
# ship
# plane
# 1
# Tesla K80

# %%
import torch.nn.functional as F

class ResNet50(nn.Module):
  def __init__(self):
    super(ResNet50,self).__init__()
    self.conv1a=nn.Conv2d(3,96,3)
    self.bn1a=nn.BatchNorm2d(96)
    self.conv1b=nn.Conv2d(96,96,3,padding=1)
    self.bn1b=nn.BatchNorm2d(96)
    self.conv1c=nn.Conv2d(96,96,3,padding=1)
    self.bn1c=nn.BatchNorm2d(96)
    self.conv1d=nn.Conv2d(96,96,3,padding=1)
    self.bn1d=nn.BatchNorm2d(96)
    self.conv1e=nn.Conv2d(96,96,3,padding=1)
    self.bn1e=nn.BatchNorm2d(96)
    self.conv1f=nn.Conv2d(96,96,3,padding=1)
    self.bn1f=nn.BatchNorm2d(96)
    self.conv1g=nn.Conv2d(96,96,3,padding=1)
    self.bn1g=nn.BatchNorm2d(96)
    self.mp1=nn.MaxPool2d(2,2)
    self.conv2a=nn.Conv2d(96,192,3,padding=1)
    self.bn2a=nn.BatchNorm2d(192)
    self.conv2b=nn.Conv2d(192,192,3,padding=1)
    self.bn2b=nn.BatchNorm2d(192)
    self.conv2c=nn.Conv2d(192,192,3,padding=1)
    self.bn2c=nn.BatchNorm2d(192)
    self.conv2d=nn.Conv2d(192,192,3,padding=1)
    self.bn2d=nn.BatchNorm2d(192)
    self.conv2e=nn.Conv2d(192,192,3,padding=1)
    self.bn2e=nn.BatchNorm2d(192)
    self.conv2f=nn.Conv2d(192,192,3,padding=1)
    self.bn2f=nn.BatchNorm2d(192)
    self.conv2g=nn.Conv2d(192,192,3,padding=1)
    self.bn2g=nn.BatchNorm2d(192)
    self.conv2h=nn.Conv2d(192,192,3,padding=1)
    self.bn2h=nn.BatchNorm2d(192)
    self.conv2i=nn.Conv2d(192,192,3,padding=1)
    self.bn2i=nn.BatchNorm2d(192)
    self.conv2j=nn.Conv2d(192,192,3,padding=1)
    self.bn2j=nn.BatchNorm2d(192)
    self.conv2k=nn.Conv2d(192,192,3,padding=1)
    self.bn2k=nn.BatchNorm2d(192)
    self.conv2l=nn.Conv2d(192,192,3,padding=1)
    self.bn2l=nn.BatchNorm2d(192)
    self.conv2m=nn.Conv2d(192,192,3,padding=1)
    self.bn2m=nn.BatchNorm2d(192)
    self.mp2=nn.MaxPool2d(2,2)
    self.conv3a=nn.Conv2d(192,256,3,padding=1)
    self.bn3a=nn.BatchNorm2d(256)
    self.conv3b=nn.Conv2d(256,256,3,padding=1)
    self.bn3b=nn.BatchNorm2d(256)
    self.conv3c=nn.Conv2d(256,256,3,padding=1)
    self.bn3c=nn.BatchNorm2d(256)
    self.conv3d=nn.Conv2d(256,256,3,padding=1)
    self.bn3d=nn.BatchNorm2d(256)
    self.conv3e=nn.Conv2d(256,256,3,padding=1)
    self.bn3e=nn.BatchNorm2d(256)
    self.conv3f=nn.Conv2d(256,256,3,padding=1)
    self.bn3f=nn.BatchNorm2d(256)
    self.conv3g=nn.Conv2d(256,256,3,padding=1)
    self.bn3g=nn.BatchNorm2d(256)
    self.conv3h=nn.Conv2d(256,256,3,padding=1)
    self.bn3h=nn.BatchNorm2d(256)
    self.conv3i=nn.Conv2d(256,256,3,padding=1)
    self.bn3i=nn.BatchNorm2d(256)
    self.conv3j=nn.Conv2d(256,256,3,padding=1)
    self.bn3j=nn.BatchNorm2d(256)
    self.conv3k=nn.Conv2d(256,256,3,padding=1)
    self.bn3k=nn.BatchNorm2d(256)
    self.conv3l=nn.Conv2d(256,256,3,padding=1)
    self.bn3l=nn.BatchNorm2d(256)
    self.conv3m=nn.Conv2d(256,256,3,padding=1)
    self.bn3m=nn.BatchNorm2d(256)
    self.mp3=nn.MaxPool2d(2,2)
    self.conv4a=nn.Conv2d(256,256,3)
    self.conv4b=nn.Conv2d(256,192,1)
    self.conv4c=nn.Conv2d(192,10,1)
    
  def forward(self,x):
    conv1a=self.bn1a(F.relu(self.conv1a(x)))
    conv1b=self.bn1b(F.relu(self.conv1b(conv1a)))
    conv1c=self.bn1c(F.relu(self.conv1c(conv1b)))
    conv1d=self.bn1d(F.relu(self.conv1d(conv1c)))+conv1a
    conv1e=self.bn1e(F.relu(self.conv1e(conv1d)))
    conv1f=self.bn1f(F.relu(self.conv1f(conv1e)))+conv1c
    conv1g=self.bn1g(F.relu(self.conv1g(conv1f)))
    mp1=self.mp1(conv1g+conv1e)
    conv2a=self.bn2a(F.relu(self.conv2a(mp1)))
    conv2b=self.bn2b(F.relu(self.conv2b(conv2a)))
    conv2c=self.bn2c(F.relu(self.conv2c(conv2b)))
    conv2d=self.bn2d(F.relu(self.conv2d(conv2c)))+conv2a
    conv2e=self.bn2e(F.relu(self.conv2e(conv2d)))
    conv2f=self.bn2f(F.relu(self.conv2f(conv2e)))+conv2c
    conv2g=self.bn2g(F.relu(self.conv2g(conv2f)))
    conv2h=self.bn2h(F.relu(self.conv2h(conv2g)))+conv2e
    conv2i=self.bn2i(F.relu(self.conv2i(conv2h)))
    conv2j=self.bn2j(F.relu(self.conv2j(conv2i)))+conv2g
    conv2k=self.bn2k(F.relu(self.conv2k(conv2j)))
    conv2l=self.bn2l(F.relu(self.conv2l(conv2k)))+conv2i
    conv2m=self.bn2m(F.relu(self.conv2m(conv2l)))
    mp2=self.mp2(conv2m+conv2k)
    conv3a=self.bn3a(F.relu(self.conv3a(mp2)))
    conv3b=self.bn3b(F.relu(self.conv3b(conv3a)))
    conv3c=self.bn3c(F.relu(self.conv3c(conv3b)))
    conv3d=self.bn3d(F.relu(self.conv3d(conv3c)))+conv3a
    conv3e=self.bn3e(F.relu(self.conv3e(conv3d)))
    conv3f=self.bn3f(F.relu(self.conv3f(conv3e)))+conv3c
    conv3g=self.bn3g(F.relu(self.conv3g(conv3f)))
    conv3h=self.bn3h(F.relu(self.conv3h(conv3g)))+conv3e
    conv3i=self.bn3i(F.relu(self.conv3i(conv3h)))
    conv3j=self.bn3j(F.relu(self.conv3j(conv3i)))+conv3g
    conv3k=self.bn3k(F.relu(self.conv3k(conv3j)))
    conv3l=self.bn3l(F.relu(self.conv3l(conv3k)))+conv3i
    conv3m=self.bn3m(F.relu(self.conv3m(conv3l)))
    mp3=self.mp3(conv3m+conv3k)
    conv4a=F.relu(self.conv4a(mp3))
    conv4b=F.relu(self.conv4b(conv4a))
    conv4c=F.relu(self.conv4c(conv4b))
    out=torch.mean(conv4c.view(conv4c.size(0),conv4c.size(1),-1),dim=2)
    return out

model=ResNet50()

loss=nn.CrossEntropyLoss()
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)


for epoch in range(n_epochs):
  for i,(features,labels) in enumerate(train_loader):
    labels_pred=model(features)
    l=loss(labels_pred,labels)
    
    l.backward()
    optimizer.step()
    optimizer.zero_grad()
    
    if(i%10==9):
      print(epoch,i,l)
  
  Filename="model_"+str(epoch)+".pth"
  torch.save(model.state_dict(),Filename)

  with torch.no_grad():
    n_samples=0
    n_correct=0
    for features,labels in test_loader:
      pred=model(features)
      _,predictions=torch.max(pred,1)
      n_correct+=(predictions==labels).sum().item()
      n_samples+=labels.shape[0]
    acc=100.0*n_correct/n_samples
    print(acc)
# Out:
# 0 9 tensor(2.2898, grad_fn=<NllLossBackward>)
# 0 19 tensor(2.2169, grad_fn=<NllLossBackward>)
# 0 29 tensor(2.2969, grad_fn=<NllLossBackward>)
# 0 39 tensor(2.3563, grad_fn=<NllLossBackward>)
# 0 49 tensor(2.2509, grad_fn=<NllLossBackward>)
# 0 59 tensor(2.2807, grad_fn=<NllLossBackward>)
# 0 69 tensor(2.3016, grad_fn=<NllLossBackward>)
# 0 79 tensor(2.2453, grad_fn=<NllLossBackward>)
# 0 89 tensor(2.2344, grad_fn=<NllLossBackward>)
# 0 99 tensor(2.2987, grad_fn=<NllLossBackward>)
# 0 109 tensor(2.1148, grad_fn=<NllLossBackward>)
# 0 119 tensor(2.5845, grad_fn=<NllLossBackward>)
# 0 129 tensor(2.1634, grad_fn=<NllLossBackward>)
# 0 139 tensor(2.2964, grad_fn=<NllLossBackward>)
# 0 149 tensor(2.0789, grad_fn=<NllLossBackward>)
# 0 159 tensor(2.1932, grad_fn=<NllLossBackward>)
# 0 169 tensor(2.3116, grad_fn=<NllLossBackward>)
# 0 179 tensor(2.0928, grad_fn=<NllLossBackward>)
# 0 189 tensor(2.1235, grad_fn=<NllLossBackward>)
# 0 199 tensor(1.9550, grad_fn=<NllLossBackward>)
# 0 209 tensor(2.2161, grad_fn=<NllLossBackward>)
# 0 219 tensor(2.1950, grad_fn=<NllLossBackward>)
# 0 229 tensor(2.0577, grad_fn=<NllLossBackward>)
# 0 239 tensor(1.8848, grad_fn=<NllLossBackward>)
# 0 249 tensor(2.2318, grad_fn=<NllLossBackward>)
# 0 259 tensor(2.0453, grad_fn=<NllLossBackward>)
# 0 269 tensor(2.1615, grad_fn=<NllLossBackward>)
# 0 279 tensor(2.0344, grad_fn=<NllLossBackward>)
# 0 289 tensor(2.1094, grad_fn=<NllLossBackward>)
# 0 299 tensor(2.0664, grad_fn=<NllLossBackward>)
# 0 309 tensor(1.9139, grad_fn=<NllLossBackward>)
# 0 319 tensor(2.0214, grad_fn=<NllLossBackward>)
# 0 329 tensor(1.9735, grad_fn=<NllLossBackward>)
# 0 339 tensor(2.0110, grad_fn=<NllLossBackward>)
# 0 349 tensor(2.2064, grad_fn=<NllLossBackward>)
# 0 359 tensor(2.1797, grad_fn=<NllLossBackward>)
# 0 369 tensor(2.1022, grad_fn=<NllLossBackward>)
# 0 379 tensor(1.9233, grad_fn=<NllLossBackward>)
# 0 389 tensor(1.7567, grad_fn=<NllLossBackward>)
# 0 399 tensor(1.7399, grad_fn=<NllLossBackward>)
# 0 409 tensor(1.9253, grad_fn=<NllLossBackward>)
# 0 419 tensor(2.3118, grad_fn=<NllLossBackward>)
# 0 429 tensor(2.0980, grad_fn=<NllLossBackward>)
# 0 439 tensor(2.0921, grad_fn=<NllLossBackward>)
# 0 449 tensor(1.9285, grad_fn=<NllLossBackward>)
# 0 459 tensor(2.0305, grad_fn=<NllLossBackward>)
# 0 469 tensor(1.7541, grad_fn=<NllLossBackward>)
# 0 479 tensor(1.7363, grad_fn=<NllLossBackward>)
# 0 489 tensor(1.8794, grad_fn=<NllLossBackward>)
# 0 499 tensor(1.7860, grad_fn=<NllLossBackward>)
# 0 509 tensor(2.5018, grad_fn=<NllLossBackward>)
# 0 519 tensor(1.8544, grad_fn=<NllLossBackward>)
# 0 529 tensor(1.9368, grad_fn=<NllLossBackward>)
# 0 539 tensor(1.9239, grad_fn=<NllLossBackward>)
# 0 549 tensor(1.9613, grad_fn=<NllLossBackward>)
# 0 559 tensor(2.0493, grad_fn=<NllLossBackward>)
# 0 569 tensor(1.9754, grad_fn=<NllLossBackward>)
# 0 579 tensor(1.4707, grad_fn=<NllLossBackward>)
# 0 589 tensor(2.0023, grad_fn=<NllLossBackward>)
# 0 599 tensor(1.6399, grad_fn=<NllLossBackward>)
# 0 609 tensor(1.9024, grad_fn=<NllLossBackward>)
# 0 619 tensor(1.9787, grad_fn=<NllLossBackward>)
# 0 629 tensor(1.8340, grad_fn=<NllLossBackward>)
# 0 639 tensor(2.1347, grad_fn=<NllLossBackward>)
# 0 649 tensor(1.8256, grad_fn=<NllLossBackward>)
# 0 659 tensor(1.7569, grad_fn=<NllLossBackward>)
# 0 669 tensor(1.6097, grad_fn=<NllLossBackward>)
# 0 679 tensor(1.8054, grad_fn=<NllLossBackward>)
# 0 689 tensor(1.8414, grad_fn=<NllLossBackward>)
# 0 699 tensor(1.7612, grad_fn=<NllLossBackward>)
# 0 709 tensor(1.7517, grad_fn=<NllLossBackward>)
# 0 719 tensor(2.0057, grad_fn=<NllLossBackward>)
# 0 729 tensor(1.7574, grad_fn=<NllLossBackward>)
# 0 739 tensor(1.4037, grad_fn=<NllLossBackward>)
# 0 749 tensor(2.0782, grad_fn=<NllLossBackward>)
# 0 759 tensor(1.8652, grad_fn=<NllLossBackward>)
# 0 769 tensor(2.0098, grad_fn=<NllLossBackward>)
# 0 779 tensor(1.8566, grad_fn=<NllLossBackward>)
# 0 789 tensor(1.4729, grad_fn=<NllLossBackward>)
# 0 799 tensor(1.9444, grad_fn=<NllLossBackward>)
# 0 809 tensor(1.8718, grad_fn=<NllLossBackward>)
# 0 819 tensor(1.7962, grad_fn=<NllLossBackward>)
# 0 829 tensor(1.8187, grad_fn=<NllLossBackward>)
# 0 839 tensor(1.5688, grad_fn=<NllLossBackward>)
# 0 849 tensor(1.7920, grad_fn=<NllLossBackward>)
# 0 859 tensor(1.7387, grad_fn=<NllLossBackward>)
# 0 869 tensor(2.0036, grad_fn=<NllLossBackward>)
# 0 879 tensor(1.8357, grad_fn=<NllLossBackward>)
# 0 889 tensor(1.8325, grad_fn=<NllLossBackward>)
# 0 899 tensor(1.6095, grad_fn=<NllLossBackward>)
# 0 909 tensor(1.9048, grad_fn=<NllLossBackward>)
# 0 919 tensor(1.7921, grad_fn=<NllLossBackward>)
# 0 929 tensor(1.6611, grad_fn=<NllLossBackward>)
# 0 939 tensor(1.7563, grad_fn=<NllLossBackward>)
# 0 949 tensor(1.8365, grad_fn=<NllLossBackward>)
# 0 959 tensor(1.5085, grad_fn=<NllLossBackward>)
# 0 969 tensor(1.6695, grad_fn=<NllLossBackward>)
# 0 979 tensor(1.5376, grad_fn=<NllLossBackward>)
# 0 989 tensor(2.0953, grad_fn=<NllLossBackward>)
# 0 999 tensor(1.6016, grad_fn=<NllLossBackward>)
# 0 1009 tensor(1.6635, grad_fn=<NllLossBackward>)
# 0 1019 tensor(1.6093, grad_fn=<NllLossBackward>)
# 0 1029 tensor(1.6251, grad_fn=<NllLossBackward>)
# 0 1039 tensor(1.5406, grad_fn=<NllLossBackward>)
# 0 1049 tensor(1.8412, grad_fn=<NllLossBackward>)
# 0 1059 tensor(1.8238, grad_fn=<NllLossBackward>)
# 0 1069 tensor(2.0604, grad_fn=<NllLossBackward>)
# 0 1079 tensor(1.7518, grad_fn=<NllLossBackward>)
# 0 1089 tensor(1.7053, grad_fn=<NllLossBackward>)
# 0 1099 tensor(1.7748, grad_fn=<NllLossBackward>)
# 0 1109 tensor(1.8061, grad_fn=<NllLossBackward>)
# 0 1119 tensor(2.0023, grad_fn=<NllLossBackward>)
# 0 1129 tensor(1.6747, grad_fn=<NllLossBackward>)
# 0 1139 tensor(1.9992, grad_fn=<NllLossBackward>)
# 0 1149 tensor(1.7422, grad_fn=<NllLossBackward>)
# 0 1159 tensor(1.8162, grad_fn=<NllLossBackward>)
# 0 1169 tensor(1.8021, grad_fn=<NllLossBackward>)
# 0 1179 tensor(1.3702, grad_fn=<NllLossBackward>)
# 0 1189 tensor(1.4543, grad_fn=<NllLossBackward>)
# 0 1199 tensor(1.7087, grad_fn=<NllLossBackward>)
# 0 1209 tensor(1.8675, grad_fn=<NllLossBackward>)
# 0 1219 tensor(1.3627, grad_fn=<NllLossBackward>)
# 0 1229 tensor(1.6743, grad_fn=<NllLossBackward>)
# 0 1239 tensor(1.8050, grad_fn=<NllLossBackward>)
# 0 1249 tensor(1.7329, grad_fn=<NllLossBackward>)
# 0 1259 tensor(1.6085, grad_fn=<NllLossBackward>)
# 0 1269 tensor(1.4036, grad_fn=<NllLossBackward>)
# 0 1279 tensor(1.9220, grad_fn=<NllLossBackward>)
# 0 1289 tensor(1.3624, grad_fn=<NllLossBackward>)
# 0 1299 tensor(1.7157, grad_fn=<NllLossBackward>)
# 0 1309 tensor(1.6292, grad_fn=<NllLossBackward>)
# 0 1319 tensor(1.5495, grad_fn=<NllLossBackward>)
# 0 1329 tensor(1.3412, grad_fn=<NllLossBackward>)
# 0 1339 tensor(1.6841, grad_fn=<NllLossBackward>)
# 0 1349 tensor(1.5163, grad_fn=<NllLossBackward>)
# 0 1359 tensor(1.6264, grad_fn=<NllLossBackward>)
# 0 1369 tensor(1.3927, grad_fn=<NllLossBackward>)
# 0 1379 tensor(1.6061, grad_fn=<NllLossBackward>)
# 0 1389 tensor(1.5990, grad_fn=<NllLossBackward>)
# 0 1399 tensor(1.5313, grad_fn=<NllLossBackward>)
# 0 1409 tensor(1.4382, grad_fn=<NllLossBackward>)
# 0 1419 tensor(1.5507, grad_fn=<NllLossBackward>)
# 0 1429 tensor(1.4352, grad_fn=<NllLossBackward>)
# 0 1439 tensor(1.6536, grad_fn=<NllLossBackward>)
# 0 1449 tensor(1.9097, grad_fn=<NllLossBackward>)
# 0 1459 tensor(1.8425, grad_fn=<NllLossBackward>)
# 0 1469 tensor(1.6071, grad_fn=<NllLossBackward>)
# 0 1479 tensor(1.7081, grad_fn=<NllLossBackward>)
# 0 1489 tensor(1.4120, grad_fn=<NllLossBackward>)
# 0 1499 tensor(1.5923, grad_fn=<NllLossBackward>)
# 0 1509 tensor(1.6725, grad_fn=<NllLossBackward>)
# 0 1519 tensor(1.7337, grad_fn=<NllLossBackward>)
# 0 1529 tensor(1.6699, grad_fn=<NllLossBackward>)
# 0 1539 tensor(1.8015, grad_fn=<NllLossBackward>)
# 0 1549 tensor(1.3600, grad_fn=<NllLossBackward>)
# 0 1559 tensor(1.4370, grad_fn=<NllLossBackward>)
# 0 1569 tensor(1.0905, grad_fn=<NllLossBackward>)
# 0 1579 tensor(1.6642, grad_fn=<NllLossBackward>)
# 0 1589 tensor(1.4796, grad_fn=<NllLossBackward>)
# 0 1599 tensor(1.5926, grad_fn=<NllLossBackward>)
# 0 1609 tensor(1.3910, grad_fn=<NllLossBackward>)
# 0 1619 tensor(1.8170, grad_fn=<NllLossBackward>)
# 0 1629 tensor(1.6007, grad_fn=<NllLossBackward>)
# 0 1639 tensor(1.4821, grad_fn=<NllLossBackward>)
# 0 1649 tensor(1.2020, grad_fn=<NllLossBackward>)
# 0 1659 tensor(1.5673, grad_fn=<NllLossBackward>)
# 0 1669 tensor(1.3165, grad_fn=<NllLossBackward>)
# 0 1679 tensor(1.4133, grad_fn=<NllLossBackward>)
# 0 1689 tensor(1.4789, grad_fn=<NllLossBackward>)
# 0 1699 tensor(1.3400, grad_fn=<NllLossBackward>)
# 0 1709 tensor(1.3076, grad_fn=<NllLossBackward>)
# 0 1719 tensor(2.2213, grad_fn=<NllLossBackward>)
# 0 1729 tensor(1.5171, grad_fn=<NllLossBackward>)
# 0 1739 tensor(1.6294, grad_fn=<NllLossBackward>)
# 0 1749 tensor(1.4319, grad_fn=<NllLossBackward>)
# 0 1759 tensor(1.5074, grad_fn=<NllLossBackward>)
# 0 1769 tensor(1.6470, grad_fn=<NllLossBackward>)
# 0 1779 tensor(1.0760, grad_fn=<NllLossBackward>)
# 0 1789 tensor(1.5381, grad_fn=<NllLossBackward>)
# 0 1799 tensor(1.5345, grad_fn=<NllLossBackward>)
# 0 1809 tensor(2.1370, grad_fn=<NllLossBackward>)
# 0 1819 tensor(1.6426, grad_fn=<NllLossBackward>)
# 0 1829 tensor(1.3253, grad_fn=<NllLossBackward>)
# 0 1839 tensor(1.3741, grad_fn=<NllLossBackward>)
# 0 1849 tensor(1.4138, grad_fn=<NllLossBackward>)
# 0 1859 tensor(1.4265, grad_fn=<NllLossBackward>)
# 0 1869 tensor(1.8263, grad_fn=<NllLossBackward>)
# 0 1879 tensor(1.5706, grad_fn=<NllLossBackward>)
# 0 1889 tensor(1.5689, grad_fn=<NllLossBackward>)
# 0 1899 tensor(1.5568, grad_fn=<NllLossBackward>)
# 0 1909 tensor(2.0519, grad_fn=<NllLossBackward>)
# 0 1919 tensor(1.7130, grad_fn=<NllLossBackward>)
# 0 1929 tensor(1.4368, grad_fn=<NllLossBackward>)
# 0 1939 tensor(1.4617, grad_fn=<NllLossBackward>)
# 0 1949 tensor(1.2811, grad_fn=<NllLossBackward>)
# 0 1959 tensor(0.9758, grad_fn=<NllLossBackward>)
# 0 1969 tensor(1.8409, grad_fn=<NllLossBackward>)
# 0 1979 tensor(0.9265, grad_fn=<NllLossBackward>)
# 0 1989 tensor(1.5985, grad_fn=<NllLossBackward>)
# 0 1999 tensor(1.3738, grad_fn=<NllLossBackward>)
# 44.84
# 1 9 tensor(0.9221, grad_fn=<NllLossBackward>)
# 1 19 tensor(1.1033, grad_fn=<NllLossBackward>)
# 1 29 tensor(1.5446, grad_fn=<NllLossBackward>)
# 1 39 tensor(1.2264, grad_fn=<NllLossBackward>)
# 1 49 tensor(1.3883, grad_fn=<NllLossBackward>)
# 1 59 tensor(1.5523, grad_fn=<NllLossBackward>)
# 1 69 tensor(1.5843, grad_fn=<NllLossBackward>)
# 1 79 tensor(1.6665, grad_fn=<NllLossBackward>)
# 1 89 tensor(1.5086, grad_fn=<NllLossBackward>)
# 1 99 tensor(1.2917, grad_fn=<NllLossBackward>)
# 1 109 tensor(1.1421, grad_fn=<NllLossBackward>)
# 1 119 tensor(1.5326, grad_fn=<NllLossBackward>)
# 1 129 tensor(1.7220, grad_fn=<NllLossBackward>)
# 1 139 tensor(1.7164, grad_fn=<NllLossBackward>)
# 1 149 tensor(1.5238, grad_fn=<NllLossBackward>)
# 1 159 tensor(1.6432, grad_fn=<NllLossBackward>)
# 1 169 tensor(1.4342, grad_fn=<NllLossBackward>)
# 1 179 tensor(1.3347, grad_fn=<NllLossBackward>)
# 1 189 tensor(1.3021, grad_fn=<NllLossBackward>)
# 1 199 tensor(1.6617, grad_fn=<NllLossBackward>)
# 1 209 tensor(1.4714, grad_fn=<NllLossBackward>)
# 1 219 tensor(1.5914, grad_fn=<NllLossBackward>)
# 1 229 tensor(1.4677, grad_fn=<NllLossBackward>)
# 1 239 tensor(1.4642, grad_fn=<NllLossBackward>)
# 1 249 tensor(1.3100, grad_fn=<NllLossBackward>)
# 1 259 tensor(1.4425, grad_fn=<NllLossBackward>)
# 1 269 tensor(1.1471, grad_fn=<NllLossBackward>)
# 1 279 tensor(1.2851, grad_fn=<NllLossBackward>)
# 1 289 tensor(1.3760, grad_fn=<NllLossBackward>)
# 1 299 tensor(1.1429, grad_fn=<NllLossBackward>)
# 1 309 tensor(1.3067, grad_fn=<NllLossBackward>)
# 1 319 tensor(1.2910, grad_fn=<NllLossBackward>)
# 1 329 tensor(1.3919, grad_fn=<NllLossBackward>)
# 1 339 tensor(1.6971, grad_fn=<NllLossBackward>)
# 1 349 tensor(1.5578, grad_fn=<NllLossBackward>)
# 1 359 tensor(1.6589, grad_fn=<NllLossBackward>)
# 1 369 tensor(1.3461, grad_fn=<NllLossBackward>)
# 1 379 tensor(1.4991, grad_fn=<NllLossBackward>)
# 1 389 tensor(1.0470, grad_fn=<NllLossBackward>)
# 1 399 tensor(2.0029, grad_fn=<NllLossBackward>)
# 1 409 tensor(1.5939, grad_fn=<NllLossBackward>)
# 1 419 tensor(1.2596, grad_fn=<NllLossBackward>)
# 1 429 tensor(1.2822, grad_fn=<NllLossBackward>)
# 1 439 tensor(1.2401, grad_fn=<NllLossBackward>)
# 1 449 tensor(1.6220, grad_fn=<NllLossBackward>)
# 1 459 tensor(1.4799, grad_fn=<NllLossBackward>)
# 1 469 tensor(1.1721, grad_fn=<NllLossBackward>)
# 1 479 tensor(1.3612, grad_fn=<NllLossBackward>)
# 1 489 tensor(1.4567, grad_fn=<NllLossBackward>)
# 1 499 tensor(1.2240, grad_fn=<NllLossBackward>)
# 1 509 tensor(1.6157, grad_fn=<NllLossBackward>)
# 1 519 tensor(1.6203, grad_fn=<NllLossBackward>)
# 1 529 tensor(1.4352, grad_fn=<NllLossBackward>)
# 1 539 tensor(1.5475, grad_fn=<NllLossBackward>)
# 1 549 tensor(1.2161, grad_fn=<NllLossBackward>)
# 1 559 tensor(1.2851, grad_fn=<NllLossBackward>)
# 1 569 tensor(1.2902, grad_fn=<NllLossBackward>)
# 1 579 tensor(1.1847, grad_fn=<NllLossBackward>)
# 1 589 tensor(1.2205, grad_fn=<NllLossBackward>)
# 1 599 tensor(1.6926, grad_fn=<NllLossBackward>)
# 1 609 tensor(1.4737, grad_fn=<NllLossBackward>)
# 1 619 tensor(1.0540, grad_fn=<NllLossBackward>)
# 1 629 tensor(1.8031, grad_fn=<NllLossBackward>)
# 1 639 tensor(1.3638, grad_fn=<NllLossBackward>)
# 1 649 tensor(1.2504, grad_fn=<NllLossBackward>)
# 1 659 tensor(1.1062, grad_fn=<NllLossBackward>)
# 1 669 tensor(1.7431, grad_fn=<NllLossBackward>)
# 1 679 tensor(1.2810, grad_fn=<NllLossBackward>)
# 1 689 tensor(1.4076, grad_fn=<NllLossBackward>)
# 1 699 tensor(1.3301, grad_fn=<NllLossBackward>)
# 1 709 tensor(1.5319, grad_fn=<NllLossBackward>)
# 1 719 tensor(1.5815, grad_fn=<NllLossBackward>)
# 1 729 tensor(1.7322, grad_fn=<NllLossBackward>)
# 1 739 tensor(1.0493, grad_fn=<NllLossBackward>)
# 1 749 tensor(1.3169, grad_fn=<NllLossBackward>)
# 1 759 tensor(1.4067, grad_fn=<NllLossBackward>)
# 1 769 tensor(1.2645, grad_fn=<NllLossBackward>)
# 1 779 tensor(0.9214, grad_fn=<NllLossBackward>)
# 1 789 tensor(1.2013, grad_fn=<NllLossBackward>)
# 1 799 tensor(1.1437, grad_fn=<NllLossBackward>)
# 1 809 tensor(1.5025, grad_fn=<NllLossBackward>)
# 1 819 tensor(1.9667, grad_fn=<NllLossBackward>)
# 1 829 tensor(1.2209, grad_fn=<NllLossBackward>)
# 1 839 tensor(1.2760, grad_fn=<NllLossBackward>)
# 1 849 tensor(1.2587, grad_fn=<NllLossBackward>)
# 1 859 tensor(1.7168, grad_fn=<NllLossBackward>)
# 1 869 tensor(1.1009, grad_fn=<NllLossBackward>)
# 1 879 tensor(1.3630, grad_fn=<NllLossBackward>)
# 1 889 tensor(1.3235, grad_fn=<NllLossBackward>)
# 1 899 tensor(1.1882, grad_fn=<NllLossBackward>)
# 1 909 tensor(1.0726, grad_fn=<NllLossBackward>)
# 1 919 tensor(1.1383, grad_fn=<NllLossBackward>)
# 1 929 tensor(1.7161, grad_fn=<NllLossBackward>)
# 1 939 tensor(1.3867, grad_fn=<NllLossBackward>)
# 1 949 tensor(1.0196, grad_fn=<NllLossBackward>)
# 1 959 tensor(1.1564, grad_fn=<NllLossBackward>)
# 1 969 tensor(1.1899, grad_fn=<NllLossBackward>)
# 1 979 tensor(1.3426, grad_fn=<NllLossBackward>)
# 1 989 tensor(1.2982, grad_fn=<NllLossBackward>)
# 1 999 tensor(1.0892, grad_fn=<NllLossBackward>)
# 1 1009 tensor(1.5314, grad_fn=<NllLossBackward>)
# 1 1019 tensor(1.2051, grad_fn=<NllLossBackward>)
# 1 1029 tensor(1.3791, grad_fn=<NllLossBackward>)
# 1 1039 tensor(1.2682, grad_fn=<NllLossBackward>)
# 1 1049 tensor(1.2644, grad_fn=<NllLossBackward>)
# 1 1059 tensor(0.8938, grad_fn=<NllLossBackward>)
# 1 1069 tensor(1.4352, grad_fn=<NllLossBackward>)
# 1 1079 tensor(1.4226, grad_fn=<NllLossBackward>)
# 1 1089 tensor(1.2571, grad_fn=<NllLossBackward>)
# 1 1099 tensor(1.2618, grad_fn=<NllLossBackward>)
# 1 1109 tensor(1.3224, grad_fn=<NllLossBackward>)
# 1 1119 tensor(1.5727, grad_fn=<NllLossBackward>)
# 1 1129 tensor(1.3105, grad_fn=<NllLossBackward>)
# 1 1139 tensor(1.1326, grad_fn=<NllLossBackward>)
# 1 1149 tensor(1.1866, grad_fn=<NllLossBackward>)
# 1 1159 tensor(1.3630, grad_fn=<NllLossBackward>)
# 1 1169 tensor(1.1453, grad_fn=<NllLossBackward>)
# 1 1179 tensor(1.4184, grad_fn=<NllLossBackward>)
# 1 1189 tensor(1.0520, grad_fn=<NllLossBackward>)
# 1 1199 tensor(1.0162, grad_fn=<NllLossBackward>)
# 1 1209 tensor(1.0244, grad_fn=<NllLossBackward>)
# 1 1219 tensor(1.1375, grad_fn=<NllLossBackward>)
# 1 1229 tensor(1.1665, grad_fn=<NllLossBackward>)
# 1 1239 tensor(1.2832, grad_fn=<NllLossBackward>)
# 1 1249 tensor(1.1552, grad_fn=<NllLossBackward>)
# 1 1259 tensor(1.5185, grad_fn=<NllLossBackward>)
# 1 1269 tensor(1.2141, grad_fn=<NllLossBackward>)
# 1 1279 tensor(1.6757, grad_fn=<NllLossBackward>)
# 1 1289 tensor(1.3755, grad_fn=<NllLossBackward>)
# 1 1299 tensor(1.2917, grad_fn=<NllLossBackward>)
# 1 1309 tensor(1.5009, grad_fn=<NllLossBackward>)
# 1 1319 tensor(1.1052, grad_fn=<NllLossBackward>)
# 1 1329 tensor(0.9686, grad_fn=<NllLossBackward>)
# 1 1339 tensor(1.3920, grad_fn=<NllLossBackward>)
# 1 1349 tensor(1.1468, grad_fn=<NllLossBackward>)
# 1 1359 tensor(1.2406, grad_fn=<NllLossBackward>)
# 1 1369 tensor(1.3166, grad_fn=<NllLossBackward>)
# 1 1379 tensor(1.3986, grad_fn=<NllLossBackward>)
# 1 1389 tensor(1.4358, grad_fn=<NllLossBackward>)
# 1 1399 tensor(0.9227, grad_fn=<NllLossBackward>)
# 1 1409 tensor(1.5163, grad_fn=<NllLossBackward>)
# 1 1419 tensor(1.4156, grad_fn=<NllLossBackward>)
# 1 1429 tensor(1.3073, grad_fn=<NllLossBackward>)
# 1 1439 tensor(1.2569, grad_fn=<NllLossBackward>)
# 1 1449 tensor(1.4181, grad_fn=<NllLossBackward>)
# 1 1459 tensor(1.3745, grad_fn=<NllLossBackward>)
# 1 1469 tensor(0.9568, grad_fn=<NllLossBackward>)
# 1 1479 tensor(1.2453, grad_fn=<NllLossBackward>)
# 1 1489 tensor(1.1090, grad_fn=<NllLossBackward>)
# 1 1499 tensor(1.3346, grad_fn=<NllLossBackward>)
# 1 1509 tensor(0.9957, grad_fn=<NllLossBackward>)
# 1 1519 tensor(1.2274, grad_fn=<NllLossBackward>)
# 1 1529 tensor(1.1463, grad_fn=<NllLossBackward>)
# 1 1539 tensor(1.3058, grad_fn=<NllLossBackward>)
# 1 1549 tensor(1.1170, grad_fn=<NllLossBackward>)
# 1 1559 tensor(1.1582, grad_fn=<NllLossBackward>)
# 1 1569 tensor(1.5375, grad_fn=<NllLossBackward>)
# 1 1579 tensor(0.8231, grad_fn=<NllLossBackward>)
# 1 1589 tensor(1.1305, grad_fn=<NllLossBackward>)
# 1 1599 tensor(1.3161, grad_fn=<NllLossBackward>)
# 1 1609 tensor(1.1581, grad_fn=<NllLossBackward>)
# 1 1619 tensor(1.5603, grad_fn=<NllLossBackward>)
# 1 1629 tensor(0.5680, grad_fn=<NllLossBackward>)
# 1 1639 tensor(1.1569, grad_fn=<NllLossBackward>)
# 1 1649 tensor(2.0279, grad_fn=<NllLossBackward>)
# 1 1659 tensor(1.0196, grad_fn=<NllLossBackward>)
# 1 1669 tensor(1.1703, grad_fn=<NllLossBackward>)
# 1 1679 tensor(1.3146, grad_fn=<NllLossBackward>)
# 1 1689 tensor(1.1939, grad_fn=<NllLossBackward>)
# 1 1699 tensor(0.9940, grad_fn=<NllLossBackward>)
# 1 1709 tensor(1.3432, grad_fn=<NllLossBackward>)
# 1 1719 tensor(1.2555, grad_fn=<NllLossBackward>)
# 1 1729 tensor(1.3086, grad_fn=<NllLossBackward>)
# 1 1739 tensor(1.6185, grad_fn=<NllLossBackward>)
# 1 1749 tensor(0.9096, grad_fn=<NllLossBackward>)
# 1 1759 tensor(0.8947, grad_fn=<NllLossBackward>)
# 1 1769 tensor(1.1928, grad_fn=<NllLossBackward>)
# 1 1779 tensor(1.0774, grad_fn=<NllLossBackward>)
# 1 1789 tensor(1.2737, grad_fn=<NllLossBackward>)
# 1 1799 tensor(0.9567, grad_fn=<NllLossBackward>)
# 1 1809 tensor(1.1511, grad_fn=<NllLossBackward>)
# 1 1819 tensor(1.0317, grad_fn=<NllLossBackward>)
# 1 1829 tensor(1.2360, grad_fn=<NllLossBackward>)
# 1 1839 tensor(1.3575, grad_fn=<NllLossBackward>)
# 1 1849 tensor(1.2297, grad_fn=<NllLossBackward>)
# 1 1859 tensor(1.7322, grad_fn=<NllLossBackward>)
# 1 1869 tensor(1.2350, grad_fn=<NllLossBackward>)
# 1 1879 tensor(1.0892, grad_fn=<NllLossBackward>)
# 1 1889 tensor(1.3614, grad_fn=<NllLossBackward>)
# 1 1899 tensor(1.0770, grad_fn=<NllLossBackward>)
# 1 1909 tensor(1.7168, grad_fn=<NllLossBackward>)
# 1 1919 tensor(1.0040, grad_fn=<NllLossBackward>)
# 1 1929 tensor(1.0096, grad_fn=<NllLossBackward>)
# 1 1939 tensor(0.8801, grad_fn=<NllLossBackward>)
# 1 1949 tensor(1.4071, grad_fn=<NllLossBackward>)
# 1 1959 tensor(1.1325, grad_fn=<NllLossBackward>)
# 1 1969 tensor(1.1720, grad_fn=<NllLossBackward>)
# 1 1979 tensor(0.9139, grad_fn=<NllLossBackward>)
# 1 1989 tensor(0.9571, grad_fn=<NllLossBackward>)
# 1 1999 tensor(1.3241, grad_fn=<NllLossBackward>)
# 57.36
# 2 9 tensor(0.7387, grad_fn=<NllLossBackward>)
# 2 19 tensor(1.2028, grad_fn=<NllLossBackward>)
# 2 29 tensor(1.2387, grad_fn=<NllLossBackward>)
# 2 39 tensor(1.0030, grad_fn=<NllLossBackward>)
# 2 49 tensor(1.2724, grad_fn=<NllLossBackward>)
# 2 59 tensor(1.4611, grad_fn=<NllLossBackward>)
# 2 69 tensor(1.1690, grad_fn=<NllLossBackward>)
# 2 79 tensor(0.8454, grad_fn=<NllLossBackward>)
# 2 89 tensor(1.0466, grad_fn=<NllLossBackward>)
# 2 99 tensor(0.9165, grad_fn=<NllLossBackward>)
# 2 109 tensor(1.5478, grad_fn=<NllLossBackward>)
# 2 119 tensor(1.2545, grad_fn=<NllLossBackward>)
# 2 129 tensor(1.1127, grad_fn=<NllLossBackward>)
# 2 139 tensor(1.0492, grad_fn=<NllLossBackward>)
# 2 149 tensor(1.2220, grad_fn=<NllLossBackward>)
# 2 159 tensor(0.8247, grad_fn=<NllLossBackward>)
# 2 169 tensor(1.3875, grad_fn=<NllLossBackward>)
# 2 179 tensor(0.6428, grad_fn=<NllLossBackward>)
# 2 189 tensor(1.1965, grad_fn=<NllLossBackward>)
# 2 199 tensor(1.0212, grad_fn=<NllLossBackward>)
# 2 209 tensor(1.2835, grad_fn=<NllLossBackward>)
# 2 219 tensor(1.1075, grad_fn=<NllLossBackward>)
# 2 229 tensor(0.8080, grad_fn=<NllLossBackward>)
# 2 239 tensor(0.9230, grad_fn=<NllLossBackward>)
# 2 249 tensor(0.9534, grad_fn=<NllLossBackward>)
# 2 259 tensor(0.8893, grad_fn=<NllLossBackward>)
# 2 269 tensor(0.9007, grad_fn=<NllLossBackward>)
# 2 279 tensor(0.8961, grad_fn=<NllLossBackward>)
# 2 289 tensor(1.6660, grad_fn=<NllLossBackward>)
# 2 299 tensor(0.9774, grad_fn=<NllLossBackward>)
# 2 309 tensor(1.4052, grad_fn=<NllLossBackward>)
# 2 319 tensor(1.2985, grad_fn=<NllLossBackward>)
# 2 329 tensor(1.0280, grad_fn=<NllLossBackward>)
# 2 339 tensor(1.2879, grad_fn=<NllLossBackward>)
# 2 349 tensor(1.1859, grad_fn=<NllLossBackward>)
# 2 359 tensor(1.2630, grad_fn=<NllLossBackward>)
# 2 369 tensor(1.0518, grad_fn=<NllLossBackward>)
# 2 379 tensor(0.8048, grad_fn=<NllLossBackward>)
# 2 389 tensor(1.0497, grad_fn=<NllLossBackward>)
# 2 399 tensor(0.8202, grad_fn=<NllLossBackward>)
# 2 409 tensor(1.4307, grad_fn=<NllLossBackward>)
# 2 419 tensor(1.1417, grad_fn=<NllLossBackward>)
# 2 429 tensor(1.2552, grad_fn=<NllLossBackward>)
# 2 439 tensor(0.9427, grad_fn=<NllLossBackward>)
# 2 449 tensor(0.8791, grad_fn=<NllLossBackward>)
# 2 459 tensor(0.9981, grad_fn=<NllLossBackward>)
# 2 469 tensor(0.7703, grad_fn=<NllLossBackward>)
# 2 479 tensor(1.2799, grad_fn=<NllLossBackward>)
# 2 489 tensor(1.0785, grad_fn=<NllLossBackward>)
# 2 499 tensor(1.2554, grad_fn=<NllLossBackward>)
# 2 509 tensor(0.9445, grad_fn=<NllLossBackward>)
# 2 519 tensor(1.0662, grad_fn=<NllLossBackward>)
# 2 529 tensor(1.0401, grad_fn=<NllLossBackward>)
# 2 539 tensor(0.8647, grad_fn=<NllLossBackward>)
# 2 549 tensor(1.1142, grad_fn=<NllLossBackward>)
# 2 559 tensor(1.0636, grad_fn=<NllLossBackward>)
# 2 569 tensor(1.0796, grad_fn=<NllLossBackward>)
# 2 579 tensor(1.1203, grad_fn=<NllLossBackward>)
# 2 589 tensor(0.8721, grad_fn=<NllLossBackward>)
# 2 599 tensor(0.9589, grad_fn=<NllLossBackward>)
# 2 609 tensor(1.0145, grad_fn=<NllLossBackward>)
# 2 619 tensor(0.9770, grad_fn=<NllLossBackward>)
# 2 629 tensor(1.1209, grad_fn=<NllLossBackward>)
# 2 639 tensor(0.9761, grad_fn=<NllLossBackward>)
# 2 649 tensor(1.3182, grad_fn=<NllLossBackward>)
# 2 659 tensor(1.2938, grad_fn=<NllLossBackward>)
# 2 669 tensor(1.0983, grad_fn=<NllLossBackward>)
# 2 679 tensor(0.8648, grad_fn=<NllLossBackward>)
# 2 689 tensor(1.7550, grad_fn=<NllLossBackward>)
# 2 699 tensor(1.2097, grad_fn=<NllLossBackward>)
# 2 709 tensor(1.1653, grad_fn=<NllLossBackward>)
# 2 719 tensor(0.9073, grad_fn=<NllLossBackward>)
# 2 729 tensor(1.5877, grad_fn=<NllLossBackward>)
# 2 739 tensor(1.2044, grad_fn=<NllLossBackward>)
# 2 749 tensor(0.8132, grad_fn=<NllLossBackward>)
# 2 759 tensor(1.6660, grad_fn=<NllLossBackward>)
# 2 769 tensor(0.7857, grad_fn=<NllLossBackward>)

# %%
filename="model_0.pth"
loaded_model=ResNet()
loaded_model.load_state_dict(torch.load(filename))
loaded_model.eval()
for i in model.parameters():
  print(i)
